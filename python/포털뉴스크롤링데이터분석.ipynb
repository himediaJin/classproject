# %%
from matplotlib import font_manager, rc

font_path = '/Windows/Fonts/batang.ttc'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import requests
import bs4

url = 'https://news.daum.net/'
res = requests.get(url)

#print(res.text)

soup = bs4.BeautifulSoup(res.text)
#print(soup)
#data = soup.select('a')
data = soup.find_all('a')
#print(data)

# %%
category_url = {
    '메인': ['https://news.daum.net/'],
    '사회': ['https://news.daum.net/society'],
    '정치': ['https://news.daum.net/politics'],
    '경제': ['https://news.daum.net/economic'],
    '국제': ['https://news.daum.net/foreign'],
    '문화': ['https://news.daum.net/culture'],
    'IT': ['https://news.daum.net/digital'],
}

# %%
for i, j in category_url.items():
    res = requests.get(j[0])
    j.append(res.text)

# %%
#print(category_url['문화'])

# %%
temp = []

for i,j in category_url.items():
    soup = bs4.BeautifulSoup(j[1])
    
    for n in soup.find_all('span', attrs={'class':'info_cp'}):        
        temp.append(n.text.strip())
        
    for n in soup.find_all('span', attrs={'class': 'info_thumb'}):
        if n.find('a') == None:
            
            if '\n' in n.text.strip():
                temp.append(n.text.strip().split('\n')[0])
            elif n.text.strip() == '':
                temp.append(n.find('img', alt=True)['alt'])
            else:
                temp.append(n.text.strip())

# %%
print(temp)
# Out:
# ['정치', '사회', '정치', '국제', '정치', '사회', '사회', '사회', '사회', '정치', '사회', '경제', '경제', '사회', '정치', '경제', '국제', '국제', '정치', '경제', '머니투데이', '노컷뉴스', '서울신문', 'YTN', '뉴스1', '대구MBC', '서울신문', '미디어오늘', '뉴스1', '뉴스1', '강원도민일보', '조선비즈', '뉴스1', '헬스조선', '노컷뉴스', '연합뉴스', '경향신문', '연합뉴스', '뉴시스', '뉴시스', '국제신문', '전주MBC', '문화일보', '연합뉴스', 'YTN', '서울신문', 'YTN', '연합뉴스TV', 'MBC', 'KBS', '한겨레', '경향신문', 'SBS', '데일리안', 'YTN', '연합뉴스', '이데일리', '뉴시스', '한국일보', '한겨레', 'YTN', '연합뉴스', '뉴시스', '매일경제', '뉴스1', '데일리안', '뉴스1', 'MBC', '연합뉴스', '뉴스1', 'kbc광주방송', 'SBS', '시사IN', '오마이뉴스', '서울신문', 'MBN', 'KBS', '채널A', '헤럴드경제', '뉴시스', '뉴스1', '뉴시스', 'KBS', '뉴시스', '연합뉴스', '뉴시스', '이데일리', '뉴시스', '연합뉴스', '국제신문', '전주MBC', '헤럴드경제', '헤럴드경제', '아시아경제', '한국경제', 'SBS', 'JTBC', '헤럴드경제', '한국경제TV', '서울경제', 'SBS Biz', '프레시안', 'YTN', '연합뉴스', '한겨레', '아시아경제', '서울신문', '뉴스1', '뉴시스', '연합뉴스', '헤럴드경제', '헤럴드경제', '뉴시스', '연합뉴스', '연합뉴스', '연합뉴스', '한겨레', '한겨레', '조선일보', '뉴시스', '서울신문', 'KBS', 'KBS', '서울신문', '오마이뉴스', 'JTBC', 'SBS Biz', 'KBS', '뉴시스', 'MBN', '서울신문', '뉴시스', '연합뉴스', '뉴시스', '헬스조선', '강원도민일보', '프레시안', '한겨레21', '헤럴드경제', '문화일보', '더스쿠프', '헤럴드경제', '오마이뉴스', '여성동아', '키즈맘', '헬스조선', '코메디닷컴', '웨딩21뉴스', '여성동아', '메종', '투어코리아', '마리끌레르', 'JTBC', '대전일보', '조선일보', '경향신문', '경향신문', '대전일보', '경향신문', '세계일보', '디지털타임스', '연합뉴스', '연합뉴스', '비즈니스워치', '조선비즈', '뉴스1', '지디넷코리아', '지디넷코리아', '머니투데이', '아이뉴스24', '지디넷코리아', '헤럴드경제', '한겨레', '뉴시스', '뉴스1', '머니투데이', '뉴시스', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '한국경제', '이데일리', '아이뉴스24', '전자신문']

# %%
#print(category_url['IT'])

# %%
temp_a = []
soup = bs4.BeautifulSoup(category_url['IT'][1])
for i in soup.find_all('span', attrs={'class': 'info_thumb'}):
    if i.find('a') == None:
        print(i.text.strip())
        temp_a.append(i.text.strip())

print(temp_a)
# Out:
# 헤럴드경제
# 한겨레
# 뉴시스
# 뉴스1
# 머니투데이
# 뉴시스
# 아이뉴스24
# 한국경제
# 조선비즈
# 조선일보
# 전자신문
# 한국경제
# 이데일리
# 아이뉴스24
# 전자신문
# ['헤럴드경제', '한겨레', '뉴시스', '뉴스1', '머니투데이', '뉴시스', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '한국경제', '이데일리', '아이뉴스24', '전자신문']

# %%
for i,j in category_url.items():
    soup = bs4.BeautifulSoup(j[1])
    # 언론사 리스트
    temp = []
    
    for n in soup.find_all('span', attrs={'class':'info_cp'}):      
        temp.append(n.text.strip())
        
    for n in soup.find_all('span', attrs={'class': 'info_thumb'}):
        if n.find('a') == None:
            
            if '\n' in n.text.strip():
                temp.append(n.text.strip().split('\n')[0])
            elif n.text.strip() == '':
                temp.append(n.find('img', alt=True)['alt'])
            else:
                temp.append(n.text.strip())
    
    j.append(temp)

# %%
print(category_url['IT'][2])
# Out:
# ['비즈니스워치', '조선비즈', '뉴스1', '지디넷코리아', '머니투데이', '아이뉴스24', '지디넷코리아', 'SBS Biz', '연합뉴스', '한국일보', '뉴스1', '헤럴드경제', '한겨레', '뉴시스', '뉴스1', '머니투데이', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '한국경제', '이데일리', '아이뉴스24', '전자신문']

# %%
import wordcloud

text = ' '.join(category_url['경제'][2])
#print(text)
wc = wordcloud.WordCloud(font_path=font_path, background_color='white')
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
import requests
import bs4

url = 'https://news.daum.net/'
res = requests.get(url)

# %%
# 모든 언론사 리스트
data = []
for i, j in category_url.items():
    if i != '메인':
        data.extend(j[2])

unique_data = list(set(data))

print(unique_data)
# Out:
# ['여성동아', '키즈맘', '중앙일보', 'SBS Biz', '연합뉴스', '조선일보', '코메디닷컴', 'YTN', '동아일보', '하이닥', '시사IN', 'kbc광주방송', '지디넷코리아', '머니투데이', '세계일보', '메종', '한국경제TV', '전자신문', '한겨레', '조선비즈', '채널A', '한국경제', '미디어오늘', 'MBN', '강원도민일보', '뉴시스', 'SBS', 'MBC', '파이낸셜뉴스', '경향신문', 'JTBC', '오마이뉴스', '서울경제', '한국일보', '디지털타임스', '아이뉴스24', '이데일리', '헬스조선', '문화일보', '농민신문', '더스쿠프', '대전일보', 'KBS', '아시아경제', '프레시안', '서울신문', '연합뉴스TV', '비즈니스워치', '헤럴드경제', '투어코리아', '웨딩21뉴스', '뉴스1']

# %%
# 분야별
rank = {}
for i in unique_data:
    rank[i]=0

for i in category_url['IT'][2]:
    rank[i] += 1
    
print(rank)
# Out:
# {'여성동아': 0, '키즈맘': 0, '중앙일보': 0, 'SBS Biz': 1, '연합뉴스': 1, '조선일보': 1, '코메디닷컴': 0, 'YTN': 0, '동아일보': 0, '하이닥': 0, '시사IN': 0, 'kbc광주방송': 0, '지디넷코리아': 2, '머니투데이': 2, '세계일보': 0, '메종': 0, '한국경제TV': 0, '전자신문': 2, '한겨레': 1, '조선비즈': 2, '채널A': 0, '한국경제': 2, '미디어오늘': 0, 'MBN': 0, '강원도민일보': 0, '뉴시스': 1, 'SBS': 0, 'MBC': 0, '파이낸셜뉴스': 0, '경향신문': 0, 'JTBC': 0, '오마이뉴스': 0, '서울경제': 0, '한국일보': 1, '디지털타임스': 0, '아이뉴스24': 3, '이데일리': 1, '헬스조선': 0, '문화일보': 0, '농민신문': 0, '더스쿠프': 0, '대전일보': 0, 'KBS': 0, '아시아경제': 0, '프레시안': 0, '서울신문': 0, '연합뉴스TV': 0, '비즈니스워치': 1, '헤럴드경제': 1, '투어코리아': 0, '웨딩21뉴스': 0, '뉴스1': 3}

# %%
import matplotlib.pyplot as plt

#print('경제' in unique_data)

#rank = {}

plt.figure(figsize=(10,10))

for i in category_url.keys():
    
    rank = {}
    
    for j  in unique_data:
        rank[j] = 0
    
    for j in category_url[i][2]:
        if i == '메인':
            continue
        rank[j] += 1
        
    x = rank.keys()
    y = rank.values()
    plt.bar(x,y,label=i)

plt.xticks(rotation=90)
plt.legend()
plt.title('분야별 언론사 랭킹')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 전체 데이터 출력
print(data)
# Out:
# ['YTN', '연합뉴스', '채널A', '뉴스1', '뉴스1', '한국경제', '문화일보', '문화일보', '한국경제', '한국경제', '아시아경제', 'MBC', '뉴스1', '뉴스1', '뉴스1', 'YTN', '연합뉴스TV', 'YTN', '서울신문', 'YTN', 'MBC', 'KBS', '한겨레', '경향신문', 'SBS', '문화일보', '아시아경제', '동아일보', '미디어오늘', '오마이뉴스', '파이낸셜뉴스', '뉴시스', '문화일보', '뉴시스', '한국경제', '뉴스1', '오마이뉴스', '뉴시스', '뉴스1', 'MBC', '연합뉴스', '뉴스1', 'kbc광주방송', 'SBS', '시사IN', '오마이뉴스', '서울신문', 'MBN', 'KBS', '채널A', '이데일리', '이데일리', '뉴스1', '뉴스1', '한국일보', '연합뉴스', '중앙일보', '머니투데이', '머니투데이', 'MBC', '뉴시스', '한국경제', '뉴시스', '동아일보', '한겨레', '뉴스1', '한국경제', '한국경제', 'SBS', 'JTBC', '헤럴드경제', '한국경제TV', '서울경제', 'SBS Biz', '프레시안', '뉴스1', '뉴시스', '뉴시스', '연합뉴스', '연합뉴스', 'JTBC', '연합뉴스', '연합뉴스', '연합뉴스', '뉴시스', '뉴시스', '연합뉴스', '뉴시스', '뉴시스', '중앙일보', '머니투데이', '뉴시스', '서울신문', 'KBS', 'KBS', '서울신문', '오마이뉴스', 'JTBC', 'SBS Biz', 'KBS', '헤럴드경제', '오마이뉴스', '여성동아', '뉴시스', 'MBN', '서울신문', '뉴시스', '뉴시스', '헬스조선', '강원도민일보', '코메디닷컴', '경향신문', '농민신문', '헤럴드경제', '문화일보', '더스쿠프', '하이닥', '코메디닷컴', '키즈맘', '헬스조선', '웨딩21뉴스', '여성동아', '메종', '투어코리아', 'JTBC', '대전일보', '조선일보', '경향신문', '경향신문', '대전일보', '경향신문', '세계일보', '디지털타임스', '비즈니스워치', '조선비즈', '뉴스1', '지디넷코리아', '머니투데이', '아이뉴스24', '지디넷코리아', 'SBS Biz', '연합뉴스', '한국일보', '뉴스1', '헤럴드경제', '한겨레', '뉴시스', '뉴스1', '머니투데이', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '한국경제', '이데일리', '아이뉴스24', '전자신문']

# %%
# 전체 랭킹
rank = {}

for i in data:
    if rank.get(i) == None :
        rank[i] = 1
    else:
        rank[i] += 1

print(rank)
# Out:
# {'YTN': 4, '연합뉴스': 10, '채널A': 2, '뉴스1': 15, '한국경제': 9, '문화일보': 5, '아시아경제': 2, 'MBC': 4, '연합뉴스TV': 1, '서울신문': 5, 'KBS': 5, '한겨레': 3, '경향신문': 5, 'SBS': 3, '동아일보': 2, '미디어오늘': 1, '오마이뉴스': 5, '파이낸셜뉴스': 1, '뉴시스': 16, 'kbc광주방송': 1, '시사IN': 1, 'MBN': 2, '이데일리': 3, '한국일보': 2, '중앙일보': 2, '머니투데이': 5, 'JTBC': 4, '헤럴드경제': 4, '한국경제TV': 1, '서울경제': 1, 'SBS Biz': 3, '프레시안': 1, '여성동아': 2, '헬스조선': 2, '강원도민일보': 1, '코메디닷컴': 2, '농민신문': 1, '더스쿠프': 1, '하이닥': 1, '키즈맘': 1, '웨딩21뉴스': 1, '메종': 1, '투어코리아': 1, '대전일보': 2, '조선일보': 2, '세계일보': 1, '디지털타임스': 1, '비즈니스워치': 1, '조선비즈': 2, '지디넷코리아': 2, '아이뉴스24': 3, '전자신문': 2}

# %%
plt.figure(figsize=(10,10))

x = rank.keys()
y = rank.values()

plt.bar(x,y)

plt.xticks(rotation=90)
plt.title('전체 분야 언론사 랭킹')
plt.show()

# %%
plt.figure(figsize=(10,10))

x = rank.keys()
y = rank.values()

plt.pie(y, labels=x)

plt.title('전체 분야 언론사 랭킹')
plt.show()
